# %%
import pandas as pd 
import numpy as np
import date

# %%
#1
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
student_data
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
for name,group in student_data.groupby(['name']):
    print(name,group)
# Out:
# Alberto Franco    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
#
#     address
# S1  street1
# David Parkes    school_code class          name date_Of_Birth   age  height  weight  \
# S6        s004    VI  David Parkes     15/09/1997   12     159      32
#
#     address
# S6  street4
# Eesha Hinton    school_code class          name date_Of_Birth   age  height  weight  \
# S4        s001    VI  Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S4  street1
# Gino Mcneill    school_code class          name date_Of_Birth   age  height  weight  \
# S2        s002     V  Gino Mcneill     17/05/2002   12     192      32
# S5        s002     V  Gino Mcneill     11/05/2002   14     151      31
#
#     address
# S2  street2
# S5  street2
# Ryan Parkes    school_code class         name date_Of_Birth   age  height  weight  address
# ...

# %%
student_data.dtypes
# Out:
# school_code       object
# class             object
# name              object
# date_Of_Birth     object
# age                int64
# height             int64
# weight             int64
# address           object
# dtype: object

# %%
#2
res = student_data.groupby(['school_code','name']).agg({'age': ['mean', 'min', 'max']})
res
# Out:
#                             age
#                            mean min max
# school_code name
# s001        Alberto Franco   12  12  12
#             Eesha Hinton     13  13  13
# s002        Gino Mcneill     13  12  14
# s003        Ryan Parkes      13  13  13
# s004        David Parkes     12  12  12

# %%
#3
res=student_data.groupby(['school_code','name'])
for name,group in res:
    print(name,group)
# Out:
# ('s001', 'Alberto Franco')    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
#
#     address
# S1  street1
# ('s001', 'Eesha Hinton')    school_code class          name date_Of_Birth   age  height  weight  \
# S4        s001    VI  Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S4  street1
# ('s002', 'Gino Mcneill')    school_code class          name date_Of_Birth   age  height  weight  \
# S2        s002     V  Gino Mcneill     17/05/2002   12     192      32
# S5        s002     V  Gino Mcneill     11/05/2002   14     151      31
#
#     address
# S2  street2
# S5  street2
# ('s003', 'Ryan Parkes')    school_code class         name date_Of_Birth   age  height  weight  address
# S3        s003    VI  Ryan Parkes     16/02/1999   13     186      33  street3
# ('s004', 'David Parkes')    school_code class          name date_Of_Birth   age  height  weight  \
# ...

# %%
#4
res = student_data.groupby('school_code')
print(list(res))
# Out:
# [('s001',    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S1  street1
# S4  street1  ), ('s002',    school_code class          name date_Of_Birth   age  height  weight  \
# S2        s002     V  Gino Mcneill     17/05/2002   12     192      32
# S5        s002     V  Gino Mcneill     11/05/2002   14     151      31
#
#     address
# S2  street2
# S5  street2  ), ('s003',    school_code class         name date_Of_Birth   age  height  weight  address
# S3        s003    VI  Ryan Parkes     16/02/1999   13     186      33  street3), ('s004',    school_code class          name date_Of_Birth   age  height  weight  \
# S6        s004    VI  David Parkes     15/09/1997   12     159      32
#
#     address
# S6  street4  )]

# %%
#5
res = student_data.groupby(['school_code','name'])
for name,group in res:
    print(name)
    print(group)
# Out:
# ('s001', 'Alberto Franco')
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
#
#     address
# S1  street1
# ('s001', 'Eesha Hinton')
#    school_code class          name date_Of_Birth   age  height  weight  \
# S4        s001    VI  Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S4  street1
# ('s002', 'Gino Mcneill')
#    school_code class          name date_Of_Birth   age  height  weight  \
# S2        s002     V  Gino Mcneill     17/05/2002   12     192      32
# S5        s002     V  Gino Mcneill     11/05/2002   14     151      31
#
#     address
# S2  street2
# S5  street2
# ('s003', 'Ryan Parkes')
#    school_code class         name date_Of_Birth   age  height  weight  address
# S3        s003    VI  Ryan Parkes     16/02/1999   13     186      33  street3
# ('s004', 'David Parkes')
# ...

# %%
res.size()
# Out:
# school_code  name
# s001         Alberto Franco    1
#              Eesha Hinton      1
# s002         Gino Mcneill      2
# s003         Ryan Parkes       1
# s004         David Parkes      1
# dtype: int64

# %%
#6
res = student_data.groupby(['school_code'])
print(res.get_group('s001'))
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S1  street1
# S4  street1

# %%
#7
orders_data = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3005,3001,3002,3009,3005,3007,3002,3004,3009,3008,3003,3002],
'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5006,5003,5002,5007,5001]})
orders_data
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5006
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5007
# 11   70013    3045.60  2012-04-25         3002         5001

# %%
res = orders_data.groupby(['customer_id']).agg({'purch_amt':['mean','max','min']})
res
# Out:
#                purch_amt
#                     mean      max      min
# customer_id
# 3001          270.650000   270.65   270.65
# 3002         2956.953333  5760.00    65.26
# 3003           75.290000    75.29    75.29
# 3004         1983.430000  1983.43  1983.43
# 3005          549.500000   948.50   150.50
# 3007         2400.600000  2400.60  2400.60
# 3008          250.450000   250.45   250.45
# 3009         1295.450000  2480.40   110.50

# %%
#8
res = orders_data.groupby(['salesman_id','customer_id']).size()
res
# Out:
# salesman_id  customer_id
# 5001         3002           3
#              3007           1
# 5002         3005           2
#              3008           1
# 5003         3009           2
# 5005         3001           1
# 5006         3004           1
# 5007         3003           1
# dtype: int64

# %%
orders_data
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5006
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5007
# 11   70013    3045.60  2012-04-25         3002         5001

# %%
#9
res = orders_data.groupby(['salesman_id','customer_id']).agg({'purch_amt':'sum'})
res
# Out:
#                          purch_amt
# salesman_id customer_id
# 5001        3002           8870.86
#             3007           2400.60
# 5002        3005           1099.00
#             3008            250.45
# 5003        3009           2590.90
# 5005        3001            270.65
# 5006        3004           1983.43
# 5007        3003             75.29

# %%
#11
orders_data
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5006
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5007
# 11   70013    3045.60  2012-04-25         3002         5001

# %%
res = orders_data.set_index('ord_date').groupby(pd.Grouper(freq='M')).agg({'purch_amt':'sum'})
res
#res=orders_data.groupby([orders_data['ord_date'].dt.month]).agg({'purch_amt':'sum'})
#res
# Out:
#             purch_amt
# ord_date
# 2012-04-30    3045.60
# 2012-05-31       0.00
# 2012-06-30     250.45
# 2012-07-31    2400.60
# 2012-08-31     185.79
# 2012-09-30    6979.15
# 2012-10-31    4679.59

# %%
orders_data['ord_date']=pd.to_datetime(orders_data['ord_date'])
orders_data
# Out:
#     ord_no  purch_amt   ord_date  customer_id  salesman_id
# 0    70001     150.50 2012-10-05         3005         5002
# 1    70009     270.65 2012-09-10         3001         5005
# 2    70002      65.26 2012-10-05         3002         5001
# 3    70004     110.50 2012-08-17         3009         5003
# 4    70007     948.50 2012-09-10         3005         5002
# 5    70005    2400.60 2012-07-27         3007         5001
# 6    70008    5760.00 2012-09-10         3002         5001
# 7    70010    1983.43 2012-10-10         3004         5006
# 8    70003    2480.40 2012-10-10         3009         5003
# 9    70012     250.45 2012-06-27         3008         5002
# 10   70011      75.29 2012-08-17         3003         5007
# 11   70013    3045.60 2012-04-25         3002         5001

# %%
#12
res=orders_data.groupby([orders_data['ord_date'].dt.year,orders_data['ord_date'].dt.month]).agg({'purch_amt':'sum'})
res
# Out:
#                    purch_amt
# ord_date ord_date
# 2012     4           3045.60
#          6            250.45
#          7           2400.60
#          8            185.79
#          9           6979.15
#          10          4679.59

# %%
#13
df = pd.DataFrame( {'X' : [10, 10, 10, 20, 30, 30, 10], 
                    'Y' : [10, 15, 11, 20, 21, 12, 14], 
                    'Z' : [22, 20, 18, 20, 13, 10, 0]})
df
# Out:
#     X   Y   Z
# 0  10  10  22
# 1  10  15  20
# 2  10  11  18
# 3  20  20  20
# 4  30  21  13
# 5  30  12  10
# 6  10  14   0

# %%
res = df.groupby('X').aggregate(lambda tdf: tdf.unique().tolist())
res
# Out:
#                    Y                Z
# X
# 10  [10, 15, 11, 14]  [22, 20, 18, 0]
# 20              [20]             [20]
# 30          [21, 12]         [13, 10]

# %%
#14
df = pd.DataFrame( {'id' : [1, 2, 1, 1, 2, 1, 2], 
                    'type' : [10, 15, 11, 20, 21, 12, 14], 
                    'book' : ['Math','English','Physics','Math','English','Physics','English']})
df
# Out:
#    id  type     book
# 0   1    10     Math
# 1   2    15  English
# 2   1    11  Physics
# 3   1    20     Math
# 4   2    21  English
# 5   1    12  Physics
# 6   2    14  English

# %%
res=df.groupby(['id','type','book']).size().unstack(fill_value=0)
res
# Out:
# book     English  Math  Physics
# id type
# 1  10          0     1        0
#    11          0     0        1
#    12          0     0        1
#    20          0     1        0
# 2  14          1     0        0
#    15          1     0        0
#    21          1     0        0

# %%
#15
df = pd.DataFrame({
    'id': [1, 1, 2, 3, 3, 4, 4, 4],
    'value': ['a', 'a', 'b', None, 'a', 'a', None, 'b']
})
df
# Out:
#    id value
# 0   1     a
# 1   1     a
# 2   2     b
# 3   3  None
# 4   3     a
# 5   4     a
# 6   4  None
# 7   4     b

# %%
df.groupby('value')['id'].nunique()
# Out:
# value
# a    3
# b    2
# Name: id, dtype: int64

# %%
#16
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
df
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
res = df.groupby('school_code')
res.groups.keys()
# Out:
# dict_keys(['s001', 's002', 's003', 's004'])

# %%
#17
df = pd.DataFrame({
'book_name':['Book1','Book2','Book3','Book4','Book1','Book2','Book3','Book5'],
'book_type':['Math','Physics','Computer','Science','Math','Physics','Computer','English'],
'book_id':[1,2,3,4,1,2,3,5]})
df
# Out:
#   book_name book_type  book_id
# 0     Book1      Math        1
# 1     Book2   Physics        2
# 2     Book3  Computer        3
# 3     Book4   Science        4
# 4     Book1      Math        1
# 5     Book2   Physics        2
# 6     Book3  Computer        3
# 7     Book5   English        5

# %%
res = df.groupby(['book_type'])
res.size()
# Out:
# book_type
# Computer    2
# English     1
# Math        2
# Physics     2
# Science     1
# dtype: int64

# %%
res =df.groupby(['book_type'])['book_type'].count().reset_index(name="count")
res
# Out:
#   book_type  count
# 0  Computer      2
# 1   English      1
# 2      Math      2
# 3   Physics      2
# 4   Science      1
